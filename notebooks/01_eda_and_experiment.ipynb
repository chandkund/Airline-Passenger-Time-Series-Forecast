# %% [markdown]
# # EDA and Experiment Notebook
#
# This notebook is for exploratory data analysis and forecasting experiments.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/AirPassengers.csv')
df.head()
